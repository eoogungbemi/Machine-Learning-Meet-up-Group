# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Imperial Business Analytics- 🐍 Python Primer 2
#
#  👨‍🏫 **Vikesh K**
#  #️⃣ **Lab 03- Pandas Overview**
#
#
#
# </div>

# %% [markdown]
#  💡  <span style='font-family:Georgia'>
#     <font color= darkred> ***A journey of a thousand miles begins with a single step- Chinese Proverb***
#     </font> 💡

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Notebook Content ✔️
#
# * Understanding Pandas 101
#     * Data manipulation
#     * Data cleaning
#     * Data Viz
#
# <div/>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imperial-Business-Analytics--🐍-Python-Primer-2" data-toc-modified-id="Imperial-Business-Analytics--🐍-Python-Primer-2-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imperial Business Analytics- 🐍 Python Primer 2</a></span></li><li><span><a href="#Notebook-Content-✔️" data-toc-modified-id="Notebook-Content-✔️-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Notebook Content ✔️</a></span></li><li><span><a href="#Pandas🐼-101" data-toc-modified-id="Pandas🐼-101-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Pandas🐼 101</a></span><ul class="toc-item"><li><span><a href="#Importing-Pandas" data-toc-modified-id="Importing-Pandas-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Importing Pandas</a></span></li><li><span><a href="#Creating-Pandas-DataFrame" data-toc-modified-id="Creating-Pandas-DataFrame-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Creating Pandas DataFrame</a></span></li><li><span><a href="#Pandas-Methods-ans-Attributes" data-toc-modified-id="Pandas-Methods-ans-Attributes-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Pandas Methods ans Attributes</a></span></li><li><span><a href="#Useful-Methods" data-toc-modified-id="Useful-Methods-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Useful Methods</a></span></li></ul></li><li><span><a href="#Case-Study-📓---Titanic" data-toc-modified-id="Case-Study-📓---Titanic-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Case Study 📓 - Titanic</a></span><ul class="toc-item"><li><span><a href="#Importing-dataset" data-toc-modified-id="Importing-dataset-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Importing dataset</a></span></li><li><span><a href="#Basic-data-investigation" data-toc-modified-id="Basic-data-investigation-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Basic data investigation</a></span></li><li><span><a href="#Changing-the-column-data-type" data-toc-modified-id="Changing-the-column-data-type-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Changing the column data type</a></span></li><li><span><a href="#Column-select" data-toc-modified-id="Column-select-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Column select</a></span></li><li><span><a href="#Row-select" data-toc-modified-id="Row-select-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Row select</a></span></li><li><span><a href="#Data-sorting" data-toc-modified-id="Data-sorting-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Data sorting</a></span></li><li><span><a href="#New-column-creation" data-toc-modified-id="New-column-creation-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>New column creation</a></span></li><li><span><a href="#Column-rename" data-toc-modified-id="Column-rename-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Column rename</a></span></li><li><span><a href="#Column-replace" data-toc-modified-id="Column-replace-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Column replace</a></span></li><li><span><a href="#Data-summary" data-toc-modified-id="Data-summary-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Data summary</a></span></li><li><span><a href="#Exploring-column-data" data-toc-modified-id="Exploring-column-data-4.11"><span class="toc-item-num">4.11&nbsp;&nbsp;</span>Exploring column data</a></span></li><li><span><a href="#Data-manipultion" data-toc-modified-id="Data-manipultion-4.12"><span class="toc-item-num">4.12&nbsp;&nbsp;</span>Data manipultion</a></span></li><li><span><a href="#Missing-values" data-toc-modified-id="Missing-values-4.13"><span class="toc-item-num">4.13&nbsp;&nbsp;</span>Missing values</a></span></li><li><span><a href="#Joining-Data" data-toc-modified-id="Joining-Data-4.14"><span class="toc-item-num">4.14&nbsp;&nbsp;</span>Joining Data</a></span></li><li><span><a href="#Inbuilt-Plotting" data-toc-modified-id="Inbuilt-Plotting-4.15"><span class="toc-item-num">4.15&nbsp;&nbsp;</span>Inbuilt Plotting</a></span></li><li><span><a href="#Exporting-a-file" data-toc-modified-id="Exporting-a-file-4.16"><span class="toc-item-num">4.16&nbsp;&nbsp;</span>Exporting a file</a></span></li></ul></li><li><span><a href="#Reference-material-📚" data-toc-modified-id="Reference-material-📚-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Reference material 📚</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# 💡 **Jupyter Shortcuts**
#
# * Use **Ctrl + /** to comment a code
# * Press H to see all the shortcuts

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# # Pandas🐼 101
#
# * 80% of the time you will be using Pandas function if you are working with Tabular data
# * It is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
# * Responsible for making python a popular choice for Data analysis

# %% [markdown]
# ## Importing Pandas

# %%
import pandas as pd
print(pd.__version__)

import os # os
os.getcwd() # current working directory
# Out:
# 2.1.0
# "G:\\My Drive\\03MT\\05-IMP-BA-Feb'23\\Module05"

# %% [markdown]
# **In case your Pandas is not updated, uncomment and run the code below**

# %%
# !pip install --upgrade pandas

# %%
# !pip install --trusted-host pypi.org --trusted-host pypi.python.org --trusted-host files.pythonhosted.org pandas

# %% [markdown]
# ## Creating Pandas DataFrame

# %% [markdown]
# ![pandas_data_structure.JPG](attachment:pandas_data_structure.JPG)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **Three ways to create a pandas df :**
#
# * Dictionary
# * List
# * External source (csv, excel, database etc)

# %%
## From dictionary 
sample_dict = {'col_1': [3, 2, 1, 0], 'col_2': ['a', 'b', 'c', 'd']}

sample_dict
# Out:
# {'col_1': [3, 2, 1, 0], 'col_2': ['a', 'b', 'c', 'd']}

# %%
pd.DataFrame(sample_dict)
# Out:
#    col_1 col_2
# 0      3     a
# 1      2     b
# 2      1     c
# 3      0     d

# %%
type(pd.DataFrame(sample_dict))
# Out:
# pandas.core.frame.DataFrame

# %%
## From List 
pd.DataFrame([['Imperial', 'UK'], ['Oxford', 'UK']], columns = ["University", "Country"])
# Out:
#   University Country
# 0   Imperial      UK
# 1     Oxford      UK

# %%
## From external source

# %%
url = 'https://raw.githubusercontent.com/vkoul/data/main/misc/titanic.csv'

df = pd.read_csv(url)
df.head(2) # show the first 2 rows of the dataset
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## Pandas Methods ans Attributes
#
# In python, **methods** are functions specfic to an object type. The pandas methods allow you to do different operations on the dataset
#
# Another aspect is **attributes** are like methods, but instead of transforming the variables or data they are used to give you more information about the data that you have. The attributes don't have () at the end.
#
# Pandas is column oriented, many of the methods are applicable at a column level

# %% [markdown]
# **Syntax of pandas methods**
#
# ![pandas-method_common-syntax-explanation.png](attachment:pandas-method_common-syntax-explanation.png)
#
# Source: J Ebener

# %%
print("There are a total of {} pandas attributes and methods".format(len(dir(pd))))
# Out:
# There are a total of 141 pandas attributes and methods

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## Useful Methods
#
# **Data Frame metadata**
#
# The below four are attributes
#
# * `df.values`
# * `df.index`
# * `df.columns`
# * `df.shape`
#
# **DataFrame Check**
#
# * `df.info()`
# * `df.head()`
# * `df.tail()`
# * `df.dtypes()`
#
#
# **DataFrame Investigation**
# * `df.duplicates()`
# * `df.isna().sum()` - missing values in a dataframe
# * `df.isna().mean()` - percentage of missing values in a dataframe
# * `df.describe()`
#
# **Column wise analysis**
# * `df.query()` - select a subset of data based on conditions
# * `df.filter()` - select only specified columns
# * `df.assign()` - add a new column to the df
# * `df.drop()` - drop columns
# * `df.sort_values(by = )` - sort dataframe based on values
# * `df.value_counts()` - frequency values of a column
#
# **Summarise**
# * `df['col'].mean()` - sort dataframe based on values
# * `df['col'].median()` - sort dataframe based on values
# * `df['col'].sum()` - sort dataframe based on values
# * `df['col'].cumsum()` - sort dataframe based on values
# * `df['col'].agg()` - sort dataframe based on values
#
# **Other operations**
#
# * `df['col'].astype()` - change the datatype of a column

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Case Study 📓 - Titanic
#
# ![titianic.jpg](attachment:titianic.jpg)

# %% [markdown]
# ## Importing dataset

# %%
url = 'https://raw.githubusercontent.com/vkoul/data/main/misc/titanic.csv'
df = pd.read_csv(url)

print('This ran')
# Out:
# This ran

# %% [markdown]
# ## Basic data investigation

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# **Syntax to call a column from a data-frame**
#
# `df['column_name']`
#
# OR
#
# `df.column_name`

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# ## Changing the column data type
#
# Often, we need to convert the datatype of a column. We will make use of the `.astype()` method to achieve this.

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# calling a single column
df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
type(df['Pclass'])
# Out:
# pandas.core.series.Series

# %%
# converting the Pclass to an object from integer
df['Pclass'].astype('object')
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: object

# %%
# Replace the original column with the new modified column
df['Pclass'] = df['Pclass'].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %% [markdown]
# ## Column select
#
# **How to select specific columns in the dataframe**

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# General syntax is :
#
# `dataframe["column_name"]`
#
# In case of multiple columns:
# `dataframe[["col1", "col2"]]`
#
# **Alternatively, we can use the `.filter()` method**
#
# `df.filter(column_name)`

# %%
df.tail(2)
# Out:
#      PassengerId  Survived Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1      1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0      3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %% [markdown]
# **Select only `Name`, `Sex` and `Age`**

# %%
col_list = ['Name', 'Age', 'Sex' ]

col_list
# Out:
# ['Name', 'Age', 'Sex']

# %%
df[col_list].head(3)
# Out:
#                                                 Name   Age     Sex
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female

# %% [markdown]
# **OR**

# %%
df.filter(col_list).head(3)
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0

# %% [markdown]
# ## Row select
#
# **Select a subset of the rows based on a condition**

# %% [markdown]
# **Select only survived passengers**

# %%
df.query('Survived == 1').head(3)
# Out:
#    PassengerId  Survived Pclass  \
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df.query('Survived == 1').shape
# Out:
# (342, 12)

# %% [markdown]
# **OR**

# %%
df["Survived"] == 1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
df[df["Survived"] == 1].head(3)
# Out:
#    PassengerId  Survived Pclass  \
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %% [markdown]
# **Mutilple Conditions**

# %%
df.query('Survived == 1 & Pclass == 3').head(3)
# Out:
#     PassengerId  Survived Pclass  \
# 2             3         1      3
# 8             9         1      3
# 10           11         1      3
#
#                                                  Name     Sex   Age  SibSp  \
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#     Parch            Ticket     Fare Cabin Embarked
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 8       2            347742  11.1333   NaN        S
# 10      1           PP 9549  16.7000    G6        S

# %%
df.query('Survived == 1 & Pclass == 3 & Sex == "female" ').head(3)
# Out:
#     PassengerId  Survived Pclass  \
# 2             3         1      3
# 8             9         1      3
# 10           11         1      3
#
#                                                  Name     Sex   Age  SibSp  \
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#     Parch            Ticket     Fare Cabin Embarked
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 8       2            347742  11.1333   NaN        S
# 10      1           PP 9549  16.7000    G6        S

# %%
# df.query("Survived == 1 & Pclass == 3 & Sex == 'female' ").head(3)

# %% [markdown]
# ## Data sorting

# %% [markdown]
# **Single Column sorting**

# %%
df.sort_values(by = 'Age', ascending = True)
# Out:
#      PassengerId  Survived Pclass                                      Name  \
# 803          804         1      3           Thomas, Master. Assad Alexander
# 755          756         1      2                 Hamalainen, Master. Viljo
# 644          645         1      3                    Baclini, Miss. Eugenie
# 469          470         1      3             Baclini, Miss. Helene Barbara
# 78            79         1      2             Caldwell, Master. Alden Gates
# ..           ...       ...    ...                                       ...
# 859          860         0      3                          Razi, Mr. Raihed
# 863          864         0      3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0      3               van Melkebeke, Mr. Philemon
# 878          879         0      3                        Laleff, Mr. Kristo
# 888          889         0      3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 803    male  0.42      0      1        2625   8.5167   NaN        C
# 755    male  0.67      1      1      250649  14.5000   NaN        S
# 644  female  0.75      2      1        2666  19.2583   NaN        C
# 469  female  0.75      2      1        2666  19.2583   NaN        C
# 78     male  0.83      0      2      248738  29.0000   NaN        S
# ..      ...   ...    ...    ...         ...      ...   ...      ...
# 859    male   NaN      0      0        2629   7.2292   NaN        C
# 863  female   NaN      8      2    CA. 2343  69.5500   NaN        S
# 868    male   NaN      0      0      345777   9.5000   NaN        S
# 878    male   NaN      0      0      349217   7.8958   NaN        S
# 888  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
#
# [891 rows x 12 columns]

# %% [markdown]
# **Multiple Column sorting**

# %%
df.sort_values(by = ['Age', 'Fare']).filter(['Age', 'Fare'])
# Out:
#       Age      Fare
# 803  0.42    8.5167
# 755  0.67   14.5000
# 469  0.75   19.2583
# 644  0.75   19.2583
# 831  0.83   18.7500
# ..    ...       ...
# 306   NaN  110.8833
# 334   NaN  133.6500
# 31    NaN  146.5208
# 527   NaN  221.7792
# 557   NaN  227.5250
#
# [891 rows x 2 columns]

# %%
df.sort_values(by = ['Fare', 'Age']).filter(['Age', 'Fare'])
# Out:
#       Age      Fare
# 302  19.0    0.0000
# 271  25.0    0.0000
# 179  36.0    0.0000
# 822  38.0    0.0000
# 806  39.0    0.0000
# ..    ...       ...
# 341  24.0  263.0000
# 438  64.0  263.0000
# 258  35.0  512.3292
# 737  35.0  512.3292
# 679  36.0  512.3292
#
# [891 rows x 2 columns]

# %%
df.sort_values(by = ['Age', 'Fare'], ascending = [False, True])
# Out:
#      PassengerId  Survived Pclass  \
# 630          631         1      1
# 851          852         0      3
# 96            97         0      1
# 493          494         0      1
# 116          117         0      3
# ..           ...       ...    ...
# 306          307         1      1
# 334          335         1      1
# 31            32         1      1
# 527          528         0      1
# 557          558         0      1
#
#                                                   Name     Sex   Age  SibSp  \
# 630               Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 851                                Svensson, Mr. Johan    male  74.0      0
# 96                           Goldschmidt, Mr. George B    male  71.0      0
# 493                            Artagaveytia, Mr. Ramon    male  71.0      0
# 116                               Connors, Mr. Patrick    male  70.5      0
# ..                                                 ...     ...   ...    ...
# 306                            Fleming, Miss. Margaret  female   NaN      0
# 334  Frauenthal, Mrs. Henry William (Clara Heinshei...  female   NaN      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 527                                 Farthing, Mr. John    male   NaN      0
# 557                                Robbins, Mr. Victor    male   NaN      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 630      0     27042   30.0000   A23        S
# 851      0    347060    7.7750   NaN        S
# 96       0  PC 17754   34.6542    A5        C
# 493      0  PC 17609   49.5042   NaN        C
# 116      0    370369    7.7500   NaN        Q
# ..     ...       ...       ...   ...      ...
# 306      0     17421  110.8833   NaN        C
# 334      0  PC 17611  133.6500   NaN        S
# 31       0  PC 17569  146.5208   B78        C
# 527      0  PC 17483  221.7792   C95        S
# 557      0  PC 17757  227.5250   NaN        C
#
# [891 rows x 12 columns]

# %% [markdown]
# ## New column creation

# %% [markdown]
# `df.assign(new_column = old_column and condition)`

# %%
survived_mapping = {1: "Yes", 0 : "No"}
survived_mapping
# Out:
# {1: 'Yes', 0: 'No'}

# %%
survived_mapping2 = dict({1:"Yes"})
survived_mapping2
# Out:
# {1: 'Yes'}

# %%
df.assign(survived_mapped =  df['Survived'].map(survived_mapping))
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# 887          888         1      1
# 888          889         0      3
# 889          890         1      1
# 890          891         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked survived_mapped
# 0        0         A/5 21171   7.2500   NaN        S              No
# 1        0          PC 17599  71.2833   C85        C             Yes
# 2        0  STON/O2. 3101282   7.9250   NaN        S             Yes
# 3        0            113803  53.1000  C123        S             Yes
# 4        0            373450   8.0500   NaN        S              No
# ..     ...               ...      ...   ...      ...             ...
# 886      0            211536  13.0000   NaN        S              No
# 887      0            112053  30.0000   B42        S             Yes
# 888      2        W./C. 6607  23.4500   NaN        S              No
# 889      0            111369  30.0000  C148        C             Yes
# 890      0            370376   7.7500   NaN        Q              No
#
# [891 rows x 13 columns]

# %% [markdown]
# **If you want to specify the location**

# %%
df.insert(2, "survived_mapped", df['Survived'].map(survived_mapping))

# %%
df.head()
# Out:
#    PassengerId  Survived survived_mapped Pclass  \
# 0            1         0              No      3
# 1            2         1             Yes      1
# 2            3         1             Yes      3
# 3            4         1             Yes      1
# 4            5         0              No      3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **Deleting a column**

# %%
# df.drop(columns = 'survived_mapped')

# %%
# del df['survived_mapped']

# %% [markdown]
# ## Column rename

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'survived_mapped', 'Pclass', 'Name', 'Sex',
#        'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
new_names = ['PassengerId', 'Survived_number', 'survived_mapped', 'Pclass', 'Name', 'Sex', # survived to Survived number
              'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
df.columns = new_names

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived_number', 'survived_mapped', 'Pclass', 'Name',
#        'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## Column replace

# %% [markdown]
# Embarked location names : Southampton, Cherbourg, and Queenstown

# %%
df[['Embarked']].head(2)
# Out:
#   Embarked
# 0        S
# 1        C

# %%
df['Embarked'] = df['Embarked'].replace({ "S": "Southampton", 
                                          "C": " Cherbourg", 
                                          "Q": "Queenstown"})

# %%
df[['Embarked']].head(2)
# Out:
#       Embarked
# 0  Southampton
# 1    Cherbourg

# %% [markdown]
# ## Data summary

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].median()
# Out:
# 28.0

# %%
df['Fare'].sum()
# Out:
# 28693.9493

# %%
df.describe() # takes only the numerical values by default
# Out:
#        PassengerId  Survived_number         Age       SibSp       Parch  \
# count   891.000000       891.000000  714.000000  891.000000  891.000000
# mean    446.000000         0.383838   29.699118    0.523008    0.381594
# std     257.353842         0.486592   14.526497    1.102743    0.806057
# min       1.000000         0.000000    0.420000    0.000000    0.000000
# 25%     223.500000         0.000000   20.125000    0.000000    0.000000
# 50%     446.000000         0.000000   28.000000    0.000000    0.000000
# 75%     668.500000         1.000000   38.000000    1.000000    0.000000
# max     891.000000         1.000000   80.000000    8.000000    6.000000
#
#              Fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %% [markdown]
# **Details on the categorical values**

# %%
df.describe(include= ['O']) # only for object
# Out:
#        survived_mapped  Pclass                     Name   Sex  Ticket  \
# count              891     891                      891   891     891
# unique               2       3                      891     2     681
# top                 No       3  Braund, Mr. Owen Harris  male  347082
# freq               549     491                        1   577       7
#
#           Cabin     Embarked
# count       204          889
# unique      147            3
# top     B96 B98  Southampton
# freq          4          644

# %% [markdown]
# **Customize the percentiles**

# %%
percentiles = [0, 0.25, 0.50, 0.60, 0.75, 0.80, 0.90, 0.95, 0.99]

# %%
df.describe(percentiles)
# Out:
#        PassengerId  Survived_number         Age       SibSp       Parch  \
# count   891.000000       891.000000  714.000000  891.000000  891.000000
# mean    446.000000         0.383838   29.699118    0.523008    0.381594
# std     257.353842         0.486592   14.526497    1.102743    0.806057
# min       1.000000         0.000000    0.420000    0.000000    0.000000
# 0%        1.000000         0.000000    0.420000    0.000000    0.000000
# 25%     223.500000         0.000000   20.125000    0.000000    0.000000
# 50%     446.000000         0.000000   28.000000    0.000000    0.000000
# 60%     535.000000         0.000000   31.800000    0.000000    0.000000
# 75%     668.500000         1.000000   38.000000    1.000000    0.000000
# 80%     713.000000         1.000000   41.000000    1.000000    1.000000
# 90%     802.000000         1.000000   50.000000    1.000000    2.000000
# 95%     846.500000         1.000000   56.000000    3.000000    2.000000
# 99%     882.100000         1.000000   65.870000    5.000000    4.000000
# max     891.000000         1.000000   80.000000    8.000000    6.000000
#
#              Fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 0%       0.000000
# 25%      7.910400
# 50%     14.454200
# 60%     21.679200
# 75%     31.000000
# 80%     39.687500
# 90%     77.958300
# 95%    112.079150
# 99%    249.006220
# max    512.329200

# %% [markdown]
# **Summary Group wise**

# %%
df.groupby('Pclass').describe()
# Out:
#        PassengerId                                                             \
#              count        mean         std   min     25%    50%    75%    max
# Pclass
# 1            216.0  461.597222  246.737616   2.0  270.75  472.0  670.5  890.0
# 2            184.0  445.956522  250.852161  10.0  234.50  435.5  668.0  887.0
# 3            491.0  439.154786  264.441453   1.0  200.00  432.0  666.5  891.0
#
#        Survived_number            ... Parch        Fare                        \
#                  count      mean  ...   75%  max  count       mean        std
# Pclass                            ...
# 1                216.0  0.629630  ...   0.0  4.0  216.0  84.154687  78.380373
# 2                184.0  0.472826  ...   1.0  3.0  184.0  20.662183  13.417399
# 3                491.0  0.242363  ...   0.0  6.0  491.0  13.675550  11.778142
#
#
#         min       25%      50%   75%       max
# Pclass
# 1       0.0  30.92395  60.2875  93.5  512.3292
# 2       0.0  13.00000  14.2500  26.0   73.5000
# 3       0.0   7.75000   8.0500  15.5   69.5500
#
# [3 rows x 48 columns]

# %% [markdown]
# ## Exploring column data

# %% [markdown]
# **How many unique enteries are there?**

# %%
# show the values
df['Embarked'].unique()
# Out:
# array(['Southampton', ' Cherbourg', 'Queenstown', nan], dtype=object)

# %%
# count the value
df['Embarked'].nunique()
# Out:
# 3

# %% [markdown]
# **What is the frequency count?**

# %%
df["Embarked"].value_counts(dropna= False) # by default its true
# Out:
# Embarked
# Southampton    644
#  Cherbourg     168
# Queenstown      77
# NaN              2
# Name: count, dtype: int64

# %%
df["Embarked"].value_counts(dropna= False, normalize = True).round(2) # get the percenatge
# Out:
# Embarked
# Southampton    0.72
#  Cherbourg     0.19
# Queenstown     0.09
# NaN            0.00
# Name: proportion, dtype: float64

# %% [markdown]
# ## Data manipultion
#
# Useful functions are (click on the links) :
#
# * [`df.pivot_table()`](https://pbpython.com/pandas-pivot-table-explained.html)
# * [`df.unstack()`](https://towardsdatascience.com/reshaping-a-dataframe-with-pandas-stack-and-unstack-925dc9ce1289)
# * [`df.melt()`](https://www.digitalocean.com/community/tutorials/pandas-melt-unmelt-pivot-function)

# %% [markdown]
# We will go through these function later in the course. Right now I want you to be aware about them

# %% [markdown]
# **What is the distrbution of Survived passengers across pclass**

# %%
df["survived_mapped"].value_counts()

# %%
df["survived_mapped"].value_counts(normalize = True).round(2)

# %%
pd.crosstab(df["survived_mapped"], df["Pclass"])

# %%
pd.crosstab(df["survived_mapped"], df["Sex"])

# %% [markdown]
# **Group by allows you to calculate numeric summaries across a categorical value**

# %% [markdown]
# ![split_apply_combine.png](attachment:split_apply_combine.png)

# %% [markdown]
# **What is the average age for each gender group**

# %%
# calculating the mean for the column
df["Age"].mean()

# %%
# calculating the mean based on Sex group
df.groupby("Sex")["Age"].mean().round(2)

# %%
# calculating the mean based on Pclass
df.groupby("Pclass")["Age"].mean().round()

# %%
# calculating the mean based on Sex group
df.groupby(["Pclass", "Sex"])["Fare"].mean().reset_index().round(2)

# %% [markdown]
# **Groupby on multiple columns and aggregations on different columns**

# %%
# # calculating the mean based on Sex group
df.groupby(["Pclass", "Sex"]).agg({'Age':'mean', 'Fare':'mean'}).round(2).reset_index()

# %% [markdown]
# ## Missing values

# %% [markdown]
# **Pandas has got extensive functions to deal with missing data**
#
# * `df.isna()` or `df.isnull()`
# * `df.notna()` or `df.notnull()`
# * `df.fillna()`
# * `df.dropna()`

# %% [markdown]
# **Get the sum of missing values across columns**

# %%
df.isna().sum()

# %% [markdown]
# **Get the sum of missing values across rows**

# %%
df.isna().sum(axis = 1)

# %% [markdown]
# **Get the percentage of missing values across columns**

# %%
df.isna().mean().round(2)

# %% [markdown]
# **Adding the missing rows as a new column to the dataframe**

# %%
df["missing_rows"] = df.isna().sum(axis = 1)

# %%
# subseting the data only for rows with more than 1 missing rows
df.query("missing_rows > 1").head(2)

# %% [markdown]
# **Find column which have atleast three missing values**

# %%
# df.isna().sum() >= 3

# %% [markdown]
# ## Joining Data

# %% [markdown]
# **While working on a problem, you would require to join datasets from different sources. Very important to understand different joins and how to do it in python**
#
# **The major joins used are: `left`, `inner`, `right`, `cross`**
#
# The below animations are from [here](https://www.garrickadenbuie.com/project/tidyexplain/#tidy-data)

# %% [markdown]
# ![original-dfs.png](attachment:original-dfs.png)

# %% [markdown]
# **Left join**
#
# ```py
# df1.merge(df2, on = 'column_name', how = 'left')
#
# ```

# %% [markdown]
# ![left-join-extra.gif](attachment:left-join-extra.gif)

# %% [markdown]
# **Inner join**
#
# ```py
# df1.merge(df2, on = 'column_name', how = 'inner')
#
# ```

# %% [markdown]
# ![inner-join.gif](attachment:inner-join.gif)

# %% [markdown]
# **Right join**
#
# ```py
# df1.merge(df2, on = 'column_name', how = 'right')
#
# ```

# %% [markdown]
# ![right-join.gif](attachment:right-join.gif)

# %% [markdown]
# **Lets create a class data-frame which we will join the to titanic dataset**

# %%
class_details = pd.DataFrame({"Pclass": [1, 2, 3] , "Class": ["FirstC", "SecondC", "ThirdC"]})
class_details

# %%
# Check the dimensions of df dataset
df.shape

# %%
df.merge(class_details, on = "Pclass", how = 'left').head(2)

# %%
df = df.merge(class_details, on = "Pclass", how = 'left')

# %%
# Check the dimensions of df dataset
df.shape

# %% [markdown]
# ## Inbuilt Plotting
#
# [Pandas has a very inbuilt method to plot quick charts](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)
#
#
# * `df.hist()` - for numeric values
# * `df['column'].plot( kind = 'Chart type')` - synatx for plotting

# %%
df.value_counts('Pclass')

# %%
df['Pclass'].value_counts().plot(kind = 'bar', title = "Bar Chart");

# %%
df['Pclass'].value_counts().plot(kind = 'pie');

# %%
df.hist(figsize = (15, 8), grid = False);

# %% [markdown]
# ## Exporting a file

# %% [markdown]
# **`csv` format**

# %%
df.to_csv("Titanic_modified_Python_processed.csv", index = False)

print("The csv file is exported to {}".format(os.getcwd()))

# %% [markdown]
# **`xlsx` format**

# %%
df.to_excel("Titanic_modified_Python_processed.xlsx", index = False)

print("The csv file is exported to {}".format(os.getcwd()))

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **💡Best Way to learn Pandas is to download datasets, prepare a list of questions and answer those questions using Pandas**💡
#
# **[Kaggle Datasets](https://www.kaggle.com/datasets) is a good website to get relevant website**

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Reference material 📚
#
# **Pandas**
# * [**Pandas Exercises**](https://github.com/guipsamora/pandas_exercises) - Highly recommend
# * [Community tutorials](https://pandas.pydata.org/docs/getting_started/tutorials.html) - very useful
# * [40 Examples to Master Pandas](https://towardsdatascience.com/40-examples-to-master-pandas-c69d058f434e)- very useful
# * [Pandas CookBook](https://github.com/jvns/pandas-cookbook)- Good reference
# * [Modern Pandas](http://tomaugspurger.github.io/modern-1-intro.html) - Good Reference
#
# * **[10 mins pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html)** - Definitely check this out to get a quick introduction to pandas
#
# * **[Data Manipulation with Pandas](https://jakevdp.github.io/PythonDataScienceHandbook/03.00-introduction-to-pandas.html)**
#
#
#
#
# **Pandas Documentation**
#
# * [Pandas Missing Value Documentation](https://pandas.pydata.org/pandas-docs/dev/user_guide/missing_data.html#)
# * [Handling Missing data](https://jakevdp.github.io/PythonDataScienceHandbook/03.04-missing-values.html)
